# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/cifar/cifar-10-python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [00:39, 4.37MB/s]
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 6
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 6:
# Image - Min Value: 7 Max Value: 249
# Image - Shape: (32, 32, 3)
# Label - Label Id: 2 Name: bird

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    return x/np.max(x)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()

# fit label binarizer to class labels whose possible values are 0 to 9
lb.fit(np.arange(10))

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function

    return lb.transform(x)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    # we know the image shape is (32, 32, 3). We can easily unpack the tuple.
    # The shape of the input into the convolutional layer after tuple unpacking becomes
    # [num_images, image_height, image_width, num_channels]
    
    return tf.placeholder(tf.float32, [None, *image_shape], 'x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, [None, n_classes], 'y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    num_images, image_height, image_width, num_channels = x_tensor.get_shape().as_list()
    # weights for the filters
    weights = tf.Variable(tf.truncated_normal([*conv_ksize, num_channels, conv_num_outputs], stddev=0.05))
    # biases for each filter
    biases = tf.Variable(tf.constant(0.05, shape=[conv_num_outputs]))
    # perform convolution
    layer = tf.nn.conv2d(x_tensor, weights, strides=[1, *conv_strides, 1], padding='SAME')
    # add biases to results of convolution
    layer += biases
    # perform relu operation
    layer = tf.nn.relu(layer)
    # Carry out max pooling operation
    # I have done MaxPool(Relu(Conv(x))). I could have also done Relu(Maxpool(Conv(x)))
    # Results will still be the same
    maxpooled_layer = tf.nn.max_pool(layer,
                            ksize=[1, *pool_ksize,1],
                            strides=[1, *pool_strides,1], padding='SAME')
    
    return maxpooled_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape()
    # We are interested in the flattened image size which is image_width*image_height*num_channels
    # there is a tensorflow function which can do this for us
    flattened_image_size = shape[1:4].num_elements()
    return tf.reshape(x_tensor, [-1, flattened_image_size] )


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()
    weights = tf.Variable(tf.truncated_normal([shape[1], num_outputs], stddev=0.05))
    biases = tf.Variable(tf.constant(0.05, shape=[num_outputs]))
    fully_conn_layer = tf.add(tf.matmul(x_tensor, weights), biases)
    fully_conn_layer = tf.nn.relu(fully_conn_layer)
    
    return fully_conn_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()
    weights = tf.Variable(tf.truncated_normal([shape[1], num_outputs], stddev=0.05))
    biases = tf.Variable(tf.constant(0.05, shape=[num_outputs]))
    output = tf.add(tf.matmul(x_tensor, weights), biases)
    
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    layer1 = conv2d_maxpool(x,
                                conv_num_outputs=16, conv_ksize=(3,3), conv_strides=(1,1),
                                pool_ksize=(2,2), pool_strides=(2,2))
    
    layer2 = conv2d_maxpool(layer1,
                                conv_num_outputs=32, conv_ksize=(3,3), conv_strides=(1,1),
                                pool_ksize=(2,2), pool_strides=(2,2))
    
    layer3 = conv2d_maxpool(layer2,
                                conv_num_outputs=64, conv_ksize=(3,3), conv_strides=(1,1),
                                pool_ksize=(2,2), pool_strides=(2,2))
    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    flattened_layer = flatten(layer3)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fully_conn_layer = fully_conn(flattened_layer, 128)
    
    # apply dropout
    dropout_layer = tf.nn.dropout(fully_conn_layer, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    output_layer = output(dropout_layer, 10)
    
    # TODO: return output
    return output_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = sess.run(cost, feed_dict={x: feature_batch, y: label_batch, keep_prob: 1.0})
    validation_accuracy = session.run(accuracy, feed_dict={x: valid_features, y: valid_labels, keep_prob: 1.0})
    print("Loss: {:>10.4f}, Validation accuracy: {:.6f}".format(loss, validation_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 256
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.1925, Validation accuracy: 0.208600
# Epoch  2, CIFAR-10 Batch 1:  Loss:     2.1171, Validation accuracy: 0.272800
# Epoch  3, CIFAR-10 Batch 1:  Loss:     2.0432, Validation accuracy: 0.343800
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.9189, Validation accuracy: 0.352400
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.8518, Validation accuracy: 0.376400
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.7690, Validation accuracy: 0.409600
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.7128, Validation accuracy: 0.410000
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.6544, Validation accuracy: 0.419400
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.6122, Validation accuracy: 0.425800
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.5580, Validation accuracy: 0.449600
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.4906, Validation accuracy: 0.453400
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.4324, Validation accuracy: 0.457000
# Epoch 13, CIFAR-10 Batch 1:  Loss:     1.3172, Validation accuracy: 0.467600
# Epoch 14, CIFAR-10 Batch 1:  Loss:     1.2648, Validation accuracy: 0.481400
# Epoch 15, CIFAR-10 Batch 1:  Loss:     1.2244, Validation accuracy: 0.490600
# Epoch 16, CIFAR-10 Batch 1:  Loss:     1.1741, Validation accuracy: 0.494400
# Epoch 17, CIFAR-10 Batch 1:  Loss:     1.1517, Validation accuracy: 0.503200
# Epoch 18, CIFAR-10 Batch 1:  Loss:     1.1225, Validation accuracy: 0.503800
# Epoch 19, CIFAR-10 Batch 1:  Loss:     1.0557, Validation accuracy: 0.502800
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.9962, Validation accuracy: 0.513000
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.9729, Validation accuracy: 0.518600
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.9086, Validation accuracy: 0.524400
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.9014, Validation accuracy: 0.520400
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.8768, Validation accuracy: 0.525000
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.8259, Validation accuracy: 0.535400
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.7942, Validation accuracy: 0.528800
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.8385, Validation accuracy: 0.528000
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.7303, Validation accuracy: 0.544600
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.7772, Validation accuracy: 0.533000
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.6660, Validation accuracy: 0.551200
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.6454, Validation accuracy: 0.552200
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.6762, Validation accuracy: 0.545800
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.5892, Validation accuracy: 0.554200
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.6023, Validation accuracy: 0.549600
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.5322, Validation accuracy: 0.562800
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.4950, Validation accuracy: 0.565800
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.4889, Validation accuracy: 0.573600
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.4702, Validation accuracy: 0.570800
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.4500, Validation accuracy: 0.576800
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.4070, Validation accuracy: 0.576200
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.3911, Validation accuracy: 0.580800
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.3653, Validation accuracy: 0.580400
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.3741, Validation accuracy: 0.576600
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.3690, Validation accuracy: 0.568800
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.3367, Validation accuracy: 0.574800
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.3342, Validation accuracy: 0.582200
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.3000, Validation accuracy: 0.580600
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.3020, Validation accuracy: 0.581400
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.2732, Validation accuracy: 0.578200
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.2731, Validation accuracy: 0.582800
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.2697, Validation accuracy: 0.589400
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.2542, Validation accuracy: 0.588600
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.2375, Validation accuracy: 0.587600
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.2303, Validation accuracy: 0.582400
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.2219, Validation accuracy: 0.587200
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.2190, Validation accuracy: 0.587800
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.1965, Validation accuracy: 0.596400
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.1807, Validation accuracy: 0.602400
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.1628, Validation accuracy: 0.606200
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.1659, Validation accuracy: 0.597200
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.1928, Validation accuracy: 0.596200
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.1619, Validation accuracy: 0.601200
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.1516, Validation accuracy: 0.606000
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.1444, Validation accuracy: 0.595000
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.1277, Validation accuracy: 0.601400
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.1531, Validation accuracy: 0.599600
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.1175, Validation accuracy: 0.606600
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.1221, Validation accuracy: 0.599600
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.1046, Validation accuracy: 0.600600
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.1073, Validation accuracy: 0.598800
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.0954, Validation accuracy: 0.602200
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.0924, Validation accuracy: 0.604000
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.1086, Validation accuracy: 0.606200
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.0984, Validation accuracy: 0.590000
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.0862, Validation accuracy: 0.601800
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.0892, Validation accuracy: 0.602600
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.0806, Validation accuracy: 0.600000
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.0939, Validation accuracy: 0.599600
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.0963, Validation accuracy: 0.601600
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.0847, Validation accuracy: 0.606400
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.0707, Validation accuracy: 0.593200
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.0732, Validation accuracy: 0.599600
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.0718, Validation accuracy: 0.597200
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.0651, Validation accuracy: 0.598400
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.0592, Validation accuracy: 0.586600
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.0867, Validation accuracy: 0.560200
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.0691, Validation accuracy: 0.586000
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.0479, Validation accuracy: 0.593800
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.0550, Validation accuracy: 0.592200
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.0558, Validation accuracy: 0.599400
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.0529, Validation accuracy: 0.602600
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.0471, Validation accuracy: 0.600400
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.0436, Validation accuracy: 0.596800
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.0429, Validation accuracy: 0.601600
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.0367, Validation accuracy: 0.600800
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.0426, Validation accuracy: 0.595400
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.0293, Validation accuracy: 0.597200
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.0499, Validation accuracy: 0.595000
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.0311, Validation accuracy: 0.598000
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.0295, Validation accuracy: 0.590800

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.1925, Validation accuracy: 0.223600
# Epoch  1, CIFAR-10 Batch 2:  Loss:     2.0942, Validation accuracy: 0.256400
# Epoch  1, CIFAR-10 Batch 3:  Loss:     1.8189, Validation accuracy: 0.263400
# Epoch  1, CIFAR-10 Batch 4:  Loss:     1.8461, Validation accuracy: 0.312800
# Epoch  1, CIFAR-10 Batch 5:  Loss:     1.8691, Validation accuracy: 0.364800
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.8858, Validation accuracy: 0.380600
# Epoch  2, CIFAR-10 Batch 2:  Loss:     1.7610, Validation accuracy: 0.397400
# Epoch  2, CIFAR-10 Batch 3:  Loss:     1.4394, Validation accuracy: 0.397000
# Epoch  2, CIFAR-10 Batch 4:  Loss:     1.5568, Validation accuracy: 0.419600
# Epoch  2, CIFAR-10 Batch 5:  Loss:     1.6048, Validation accuracy: 0.438400
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.7102, Validation accuracy: 0.442800
# Epoch  3, CIFAR-10 Batch 2:  Loss:     1.5107, Validation accuracy: 0.455800
# Epoch  3, CIFAR-10 Batch 3:  Loss:     1.3116, Validation accuracy: 0.460200
# Epoch  3, CIFAR-10 Batch 4:  Loss:     1.4428, Validation accuracy: 0.462800
# Epoch  3, CIFAR-10 Batch 5:  Loss:     1.5559, Validation accuracy: 0.468800
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.5809, Validation accuracy: 0.488400
# Epoch  4, CIFAR-10 Batch 2:  Loss:     1.4237, Validation accuracy: 0.496800
# Epoch  4, CIFAR-10 Batch 3:  Loss:     1.2341, Validation accuracy: 0.496600
# Epoch  4, CIFAR-10 Batch 4:  Loss:     1.3012, Validation accuracy: 0.500000
# Epoch  4, CIFAR-10 Batch 5:  Loss:     1.4802, Validation accuracy: 0.494800
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.4728, Validation accuracy: 0.513600
# Epoch  5, CIFAR-10 Batch 2:  Loss:     1.2750, Validation accuracy: 0.513600
# Epoch  5, CIFAR-10 Batch 3:  Loss:     1.1155, Validation accuracy: 0.517400
# Epoch  5, CIFAR-10 Batch 4:  Loss:     1.1871, Validation accuracy: 0.537200
# Epoch  5, CIFAR-10 Batch 5:  Loss:     1.3767, Validation accuracy: 0.525200
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.4020, Validation accuracy: 0.532000
# Epoch  6, CIFAR-10 Batch 2:  Loss:     1.1816, Validation accuracy: 0.538600
# Epoch  6, CIFAR-10 Batch 3:  Loss:     1.0205, Validation accuracy: 0.541000
# Epoch  6, CIFAR-10 Batch 4:  Loss:     1.1249, Validation accuracy: 0.555800
# Epoch  6, CIFAR-10 Batch 5:  Loss:     1.3361, Validation accuracy: 0.533600
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.2811, Validation accuracy: 0.543400
# Epoch  7, CIFAR-10 Batch 2:  Loss:     1.1116, Validation accuracy: 0.549600
# Epoch  7, CIFAR-10 Batch 3:  Loss:     0.9537, Validation accuracy: 0.557600
# Epoch  7, CIFAR-10 Batch 4:  Loss:     1.0197, Validation accuracy: 0.564200
# Epoch  7, CIFAR-10 Batch 5:  Loss:     1.1889, Validation accuracy: 0.563000
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.2203, Validation accuracy: 0.551400
# Epoch  8, CIFAR-10 Batch 2:  Loss:     1.0148, Validation accuracy: 0.559800
# Epoch  8, CIFAR-10 Batch 3:  Loss:     0.8963, Validation accuracy: 0.564200
# Epoch  8, CIFAR-10 Batch 4:  Loss:     0.9547, Validation accuracy: 0.581600
# Epoch  8, CIFAR-10 Batch 5:  Loss:     1.1005, Validation accuracy: 0.575600
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.1649, Validation accuracy: 0.573600
# Epoch  9, CIFAR-10 Batch 2:  Loss:     0.9542, Validation accuracy: 0.574600
# Epoch  9, CIFAR-10 Batch 3:  Loss:     0.8227, Validation accuracy: 0.587200
# Epoch  9, CIFAR-10 Batch 4:  Loss:     0.9038, Validation accuracy: 0.592200
# Epoch  9, CIFAR-10 Batch 5:  Loss:     1.0259, Validation accuracy: 0.589200
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.0845, Validation accuracy: 0.584800
# Epoch 10, CIFAR-10 Batch 2:  Loss:     0.8689, Validation accuracy: 0.586600
# Epoch 10, CIFAR-10 Batch 3:  Loss:     0.7708, Validation accuracy: 0.598800
# Epoch 10, CIFAR-10 Batch 4:  Loss:     0.8376, Validation accuracy: 0.607400
# Epoch 10, CIFAR-10 Batch 5:  Loss:     0.9676, Validation accuracy: 0.600800
# Epoch 11, CIFAR-10 Batch 1:  Loss:     0.9978, Validation accuracy: 0.593200
# Epoch 11, CIFAR-10 Batch 2:  Loss:     0.8236, Validation accuracy: 0.605600
# Epoch 11, CIFAR-10 Batch 3:  Loss:     0.6988, Validation accuracy: 0.604800
# Epoch 11, CIFAR-10 Batch 4:  Loss:     0.7473, Validation accuracy: 0.624600
# Epoch 11, CIFAR-10 Batch 5:  Loss:     0.8988, Validation accuracy: 0.619200
# Epoch 12, CIFAR-10 Batch 1:  Loss:     0.9602, Validation accuracy: 0.620600
# Epoch 12, CIFAR-10 Batch 2:  Loss:     0.7766, Validation accuracy: 0.615600
# Epoch 12, CIFAR-10 Batch 3:  Loss:     0.6800, Validation accuracy: 0.619600
# Epoch 12, CIFAR-10 Batch 4:  Loss:     0.7047, Validation accuracy: 0.625600
# Epoch 12, CIFAR-10 Batch 5:  Loss:     0.8287, Validation accuracy: 0.621600
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.8844, Validation accuracy: 0.617400
# Epoch 13, CIFAR-10 Batch 2:  Loss:     0.7119, Validation accuracy: 0.638000
# Epoch 13, CIFAR-10 Batch 3:  Loss:     0.6185, Validation accuracy: 0.635400
# Epoch 13, CIFAR-10 Batch 4:  Loss:     0.6830, Validation accuracy: 0.637000
# Epoch 13, CIFAR-10 Batch 5:  Loss:     0.7977, Validation accuracy: 0.624600
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.8345, Validation accuracy: 0.626400
# Epoch 14, CIFAR-10 Batch 2:  Loss:     0.6403, Validation accuracy: 0.637600
# Epoch 14, CIFAR-10 Batch 3:  Loss:     0.5645, Validation accuracy: 0.645000
# Epoch 14, CIFAR-10 Batch 4:  Loss:     0.6187, Validation accuracy: 0.645200
# Epoch 14, CIFAR-10 Batch 5:  Loss:     0.7322, Validation accuracy: 0.645400
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.7582, Validation accuracy: 0.635200
# Epoch 15, CIFAR-10 Batch 2:  Loss:     0.6255, Validation accuracy: 0.651800
# Epoch 15, CIFAR-10 Batch 3:  Loss:     0.5528, Validation accuracy: 0.649200
# Epoch 15, CIFAR-10 Batch 4:  Loss:     0.5700, Validation accuracy: 0.656600
# Epoch 15, CIFAR-10 Batch 5:  Loss:     0.6570, Validation accuracy: 0.649800
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.7261, Validation accuracy: 0.645200
# Epoch 16, CIFAR-10 Batch 2:  Loss:     0.5800, Validation accuracy: 0.655200
# Epoch 16, CIFAR-10 Batch 3:  Loss:     0.4988, Validation accuracy: 0.661200
# Epoch 16, CIFAR-10 Batch 4:  Loss:     0.5492, Validation accuracy: 0.665400
# Epoch 16, CIFAR-10 Batch 5:  Loss:     0.6126, Validation accuracy: 0.654400
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.6462, Validation accuracy: 0.663000
# Epoch 17, CIFAR-10 Batch 2:  Loss:     0.5750, Validation accuracy: 0.665400
# Epoch 17, CIFAR-10 Batch 3:  Loss:     0.4585, Validation accuracy: 0.666600
# Epoch 17, CIFAR-10 Batch 4:  Loss:     0.5231, Validation accuracy: 0.668400
# Epoch 17, CIFAR-10 Batch 5:  Loss:     0.5879, Validation accuracy: 0.661000
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.6096, Validation accuracy: 0.670200
# Epoch 18, CIFAR-10 Batch 2:  Loss:     0.5042, Validation accuracy: 0.670000
# Epoch 18, CIFAR-10 Batch 3:  Loss:     0.4549, Validation accuracy: 0.665000
# Epoch 18, CIFAR-10 Batch 4:  Loss:     0.5126, Validation accuracy: 0.662200
# Epoch 18, CIFAR-10 Batch 5:  Loss:     0.5243, Validation accuracy: 0.655000
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.5586, Validation accuracy: 0.660000
# Epoch 19, CIFAR-10 Batch 2:  Loss:     0.4754, Validation accuracy: 0.667000
# Epoch 19, CIFAR-10 Batch 3:  Loss:     0.4098, Validation accuracy: 0.653000
# Epoch 19, CIFAR-10 Batch 4:  Loss:     0.4599, Validation accuracy: 0.673200
# Epoch 19, CIFAR-10 Batch 5:  Loss:     0.4924, Validation accuracy: 0.667600
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.5597, Validation accuracy: 0.656200
# Epoch 20, CIFAR-10 Batch 2:  Loss:     0.5168, Validation accuracy: 0.676000
# Epoch 20, CIFAR-10 Batch 3:  Loss:     0.4041, Validation accuracy: 0.658200
# Epoch 20, CIFAR-10 Batch 4:  Loss:     0.4539, Validation accuracy: 0.668000
# Epoch 20, CIFAR-10 Batch 5:  Loss:     0.4549, Validation accuracy: 0.669800
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.5312, Validation accuracy: 0.671600
# Epoch 21, CIFAR-10 Batch 2:  Loss:     0.4525, Validation accuracy: 0.680600
# Epoch 21, CIFAR-10 Batch 3:  Loss:     0.3608, Validation accuracy: 0.668000
# Epoch 21, CIFAR-10 Batch 4:  Loss:     0.4204, Validation accuracy: 0.686200
# Epoch 21, CIFAR-10 Batch 5:  Loss:     0.4287, Validation accuracy: 0.674800
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.4823, Validation accuracy: 0.676600
# Epoch 22, CIFAR-10 Batch 2:  Loss:     0.4412, Validation accuracy: 0.687200
# Epoch 22, CIFAR-10 Batch 3:  Loss:     0.3533, Validation accuracy: 0.669400
# Epoch 22, CIFAR-10 Batch 4:  Loss:     0.4043, Validation accuracy: 0.684200
# Epoch 22, CIFAR-10 Batch 5:  Loss:     0.3935, Validation accuracy: 0.680400
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.4802, Validation accuracy: 0.679800
# Epoch 23, CIFAR-10 Batch 2:  Loss:     0.3949, Validation accuracy: 0.696400
# Epoch 23, CIFAR-10 Batch 3:  Loss:     0.3531, Validation accuracy: 0.679800
# Epoch 23, CIFAR-10 Batch 4:  Loss:     0.4072, Validation accuracy: 0.683200
# Epoch 23, CIFAR-10 Batch 5:  Loss:     0.3655, Validation accuracy: 0.683200
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.4711, Validation accuracy: 0.675400
# Epoch 24, CIFAR-10 Batch 2:  Loss:     0.4386, Validation accuracy: 0.683000
# Epoch 24, CIFAR-10 Batch 3:  Loss:     0.3292, Validation accuracy: 0.681600
# Epoch 24, CIFAR-10 Batch 4:  Loss:     0.3814, Validation accuracy: 0.694800
# Epoch 24, CIFAR-10 Batch 5:  Loss:     0.3577, Validation accuracy: 0.687800
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.4240, Validation accuracy: 0.678200
# Epoch 25, CIFAR-10 Batch 2:  Loss:     0.3937, Validation accuracy: 0.689200
# Epoch 25, CIFAR-10 Batch 3:  Loss:     0.2946, Validation accuracy: 0.689000
# Epoch 25, CIFAR-10 Batch 4:  Loss:     0.3571, Validation accuracy: 0.687600
# Epoch 25, CIFAR-10 Batch 5:  Loss:     0.3342, Validation accuracy: 0.692600
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.4189, Validation accuracy: 0.693600
# Epoch 26, CIFAR-10 Batch 2:  Loss:     0.3800, Validation accuracy: 0.689400
# Epoch 26, CIFAR-10 Batch 3:  Loss:     0.2944, Validation accuracy: 0.688200
# Epoch 26, CIFAR-10 Batch 4:  Loss:     0.3457, Validation accuracy: 0.695200
# Epoch 26, CIFAR-10 Batch 5:  Loss:     0.3203, Validation accuracy: 0.679600
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.3948, Validation accuracy: 0.699800
# Epoch 27, CIFAR-10 Batch 2:  Loss:     0.3527, Validation accuracy: 0.686600
# Epoch 27, CIFAR-10 Batch 3:  Loss:     0.2744, Validation accuracy: 0.691600
# Epoch 27, CIFAR-10 Batch 4:  Loss:     0.3103, Validation accuracy: 0.696800
# Epoch 27, CIFAR-10 Batch 5:  Loss:     0.3132, Validation accuracy: 0.692800
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.3639, Validation accuracy: 0.697200
# Epoch 28, CIFAR-10 Batch 2:  Loss:     0.3477, Validation accuracy: 0.690600
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.2653, Validation accuracy: 0.697200
# Epoch 28, CIFAR-10 Batch 4:  Loss:     0.3003, Validation accuracy: 0.696400
# Epoch 28, CIFAR-10 Batch 5:  Loss:     0.3161, Validation accuracy: 0.684200
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.3700, Validation accuracy: 0.700600
# Epoch 29, CIFAR-10 Batch 2:  Loss:     0.3427, Validation accuracy: 0.696000
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.2279, Validation accuracy: 0.703200
# Epoch 29, CIFAR-10 Batch 4:  Loss:     0.2846, Validation accuracy: 0.699800
# Epoch 29, CIFAR-10 Batch 5:  Loss:     0.2855, Validation accuracy: 0.689400
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.3490, Validation accuracy: 0.706000
# Epoch 30, CIFAR-10 Batch 2:  Loss:     0.3252, Validation accuracy: 0.696600
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.2168, Validation accuracy: 0.696800
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.2851, Validation accuracy: 0.693600
# Epoch 30, CIFAR-10 Batch 5:  Loss:     0.2447, Validation accuracy: 0.691800
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.2989, Validation accuracy: 0.697400
# Epoch 31, CIFAR-10 Batch 2:  Loss:     0.3105, Validation accuracy: 0.697200
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.2019, Validation accuracy: 0.709200
# Epoch 31, CIFAR-10 Batch 4:  Loss:     0.2836, Validation accuracy: 0.700400
# Epoch 31, CIFAR-10 Batch 5:  Loss:     0.2268, Validation accuracy: 0.694200
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.2992, Validation accuracy: 0.702400
# Epoch 32, CIFAR-10 Batch 2:  Loss:     0.2642, Validation accuracy: 0.696800
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.2080, Validation accuracy: 0.704000
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.2715, Validation accuracy: 0.692800
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.2368, Validation accuracy: 0.696000
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.2880, Validation accuracy: 0.705600
# Epoch 33, CIFAR-10 Batch 2:  Loss:     0.2655, Validation accuracy: 0.699800
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.2165, Validation accuracy: 0.702800
# Epoch 33, CIFAR-10 Batch 4:  Loss:     0.2380, Validation accuracy: 0.688200
# Epoch 33, CIFAR-10 Batch 5:  Loss:     0.2154, Validation accuracy: 0.696000
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.2702, Validation accuracy: 0.702600
# Epoch 34, CIFAR-10 Batch 2:  Loss:     0.2577, Validation accuracy: 0.695800
# Epoch 34, CIFAR-10 Batch 3:  Loss:     0.2079, Validation accuracy: 0.709000
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.2067, Validation accuracy: 0.704000
# Epoch 34, CIFAR-10 Batch 5:  Loss:     0.1902, Validation accuracy: 0.687000
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.2647, Validation accuracy: 0.706400
# Epoch 35, CIFAR-10 Batch 2:  Loss:     0.2322, Validation accuracy: 0.707600
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.1724, Validation accuracy: 0.708200
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.2047, Validation accuracy: 0.707400
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.1840, Validation accuracy: 0.700400
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.2778, Validation accuracy: 0.707200
# Epoch 36, CIFAR-10 Batch 2:  Loss:     0.2225, Validation accuracy: 0.708800
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.1905, Validation accuracy: 0.705400
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.2016, Validation accuracy: 0.709600
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.1878, Validation accuracy: 0.697400
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.2536, Validation accuracy: 0.702000
# Epoch 37, CIFAR-10 Batch 2:  Loss:     0.2230, Validation accuracy: 0.699400
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.1519, Validation accuracy: 0.707600
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.1719, Validation accuracy: 0.700000
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.1801, Validation accuracy: 0.702000
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.2454, Validation accuracy: 0.707800
# Epoch 38, CIFAR-10 Batch 2:  Loss:     0.2349, Validation accuracy: 0.705800
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.1493, Validation accuracy: 0.703200
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.1967, Validation accuracy: 0.707000
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.1732, Validation accuracy: 0.700400
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.2357, Validation accuracy: 0.714000
# Epoch 39, CIFAR-10 Batch 2:  Loss:     0.2100, Validation accuracy: 0.710000
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.1399, Validation accuracy: 0.710800
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.1729, Validation accuracy: 0.700200
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.1562, Validation accuracy: 0.698200
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.2007, Validation accuracy: 0.707800
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.1982, Validation accuracy: 0.707800
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.1342, Validation accuracy: 0.706000
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.1822, Validation accuracy: 0.695400
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.1628, Validation accuracy: 0.688200
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.2429, Validation accuracy: 0.700000
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.2002, Validation accuracy: 0.701000
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.1403, Validation accuracy: 0.713200
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.1864, Validation accuracy: 0.713200
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.1683, Validation accuracy: 0.699000
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.2220, Validation accuracy: 0.703600
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.1727, Validation accuracy: 0.704200
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.1359, Validation accuracy: 0.709600
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.1681, Validation accuracy: 0.708400
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.1443, Validation accuracy: 0.702600
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.2261, Validation accuracy: 0.702400
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.1795, Validation accuracy: 0.711600
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.1261, Validation accuracy: 0.713800
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.1600, Validation accuracy: 0.712000
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.1413, Validation accuracy: 0.710200
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.2219, Validation accuracy: 0.710400
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.1794, Validation accuracy: 0.700200
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.1219, Validation accuracy: 0.716000
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.1423, Validation accuracy: 0.715800
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.1247, Validation accuracy: 0.708000
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.1911, Validation accuracy: 0.707000
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.1739, Validation accuracy: 0.708200
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.1181, Validation accuracy: 0.725000
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.1421, Validation accuracy: 0.718800
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.1535, Validation accuracy: 0.709000
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.2021, Validation accuracy: 0.706800
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.1683, Validation accuracy: 0.699800
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.1049, Validation accuracy: 0.719600
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.1224, Validation accuracy: 0.719000
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.1238, Validation accuracy: 0.713800
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.1808, Validation accuracy: 0.708800
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.1617, Validation accuracy: 0.698400
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.1050, Validation accuracy: 0.721000
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.1491, Validation accuracy: 0.711600
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.1208, Validation accuracy: 0.714800
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.1767, Validation accuracy: 0.707400
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.1531, Validation accuracy: 0.699800
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.0980, Validation accuracy: 0.716200
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.1276, Validation accuracy: 0.710800
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.1059, Validation accuracy: 0.704400
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.1722, Validation accuracy: 0.710600
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.1606, Validation accuracy: 0.709400
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.1112, Validation accuracy: 0.712200
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.1266, Validation accuracy: 0.721200
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.1103, Validation accuracy: 0.717400
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.2214, Validation accuracy: 0.700000
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.1648, Validation accuracy: 0.685000
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.0950, Validation accuracy: 0.715800
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.1319, Validation accuracy: 0.709800
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.1209, Validation accuracy: 0.709600
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.1733, Validation accuracy: 0.710800
# Epoch 51, CIFAR-10 Batch 2:  Loss:     0.1514, Validation accuracy: 0.701800
# Epoch 51, CIFAR-10 Batch 3:  Loss:     0.0812, Validation accuracy: 0.709000
# Epoch 51, CIFAR-10 Batch 4:  Loss:     0.1334, Validation accuracy: 0.711400
# Epoch 51, CIFAR-10 Batch 5:  Loss:     0.1173, Validation accuracy: 0.713600
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.1426, Validation accuracy: 0.712200
# Epoch 52, CIFAR-10 Batch 2:  Loss:     0.1614, Validation accuracy: 0.695800
# Epoch 52, CIFAR-10 Batch 3:  Loss:     0.0857, Validation accuracy: 0.708400
# Epoch 52, CIFAR-10 Batch 4:  Loss:     0.1196, Validation accuracy: 0.716200
# Epoch 52, CIFAR-10 Batch 5:  Loss:     0.0983, Validation accuracy: 0.710400
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.1578, Validation accuracy: 0.710200
# Epoch 53, CIFAR-10 Batch 2:  Loss:     0.1292, Validation accuracy: 0.711000
# Epoch 53, CIFAR-10 Batch 3:  Loss:     0.0815, Validation accuracy: 0.715400
# Epoch 53, CIFAR-10 Batch 4:  Loss:     0.1187, Validation accuracy: 0.713800
# Epoch 53, CIFAR-10 Batch 5:  Loss:     0.1046, Validation accuracy: 0.714000
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.1263, Validation accuracy: 0.706400
# Epoch 54, CIFAR-10 Batch 2:  Loss:     0.1349, Validation accuracy: 0.705400
# Epoch 54, CIFAR-10 Batch 3:  Loss:     0.0744, Validation accuracy: 0.708800
# Epoch 54, CIFAR-10 Batch 4:  Loss:     0.1095, Validation accuracy: 0.715800
# Epoch 54, CIFAR-10 Batch 5:  Loss:     0.0969, Validation accuracy: 0.707000
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.1580, Validation accuracy: 0.707200
# Epoch 55, CIFAR-10 Batch 2:  Loss:     0.1251, Validation accuracy: 0.704600
# Epoch 55, CIFAR-10 Batch 3:  Loss:     0.0744, Validation accuracy: 0.713000
# Epoch 55, CIFAR-10 Batch 4:  Loss:     0.1057, Validation accuracy: 0.717800
# Epoch 55, CIFAR-10 Batch 5:  Loss:     0.0941, Validation accuracy: 0.714400
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.1481, Validation accuracy: 0.705400
# Epoch 56, CIFAR-10 Batch 2:  Loss:     0.1504, Validation accuracy: 0.710600
# Epoch 56, CIFAR-10 Batch 3:  Loss:     0.0860, Validation accuracy: 0.718600
# Epoch 56, CIFAR-10 Batch 4:  Loss:     0.1079, Validation accuracy: 0.710200
# Epoch 56, CIFAR-10 Batch 5:  Loss:     0.0794, Validation accuracy: 0.715800
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.1577, Validation accuracy: 0.696000
# Epoch 57, CIFAR-10 Batch 2:  Loss:     0.1238, Validation accuracy: 0.707800
# Epoch 57, CIFAR-10 Batch 3:  Loss:     0.0839, Validation accuracy: 0.707800
# Epoch 57, CIFAR-10 Batch 4:  Loss:     0.1106, Validation accuracy: 0.706600
# Epoch 57, CIFAR-10 Batch 5:  Loss:     0.0988, Validation accuracy: 0.704400
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.1352, Validation accuracy: 0.702400
# Epoch 58, CIFAR-10 Batch 2:  Loss:     0.1379, Validation accuracy: 0.707400
# Epoch 58, CIFAR-10 Batch 3:  Loss:     0.0843, Validation accuracy: 0.711000
# Epoch 58, CIFAR-10 Batch 4:  Loss:     0.1067, Validation accuracy: 0.704600
# Epoch 58, CIFAR-10 Batch 5:  Loss:     0.0920, Validation accuracy: 0.704200
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.1318, Validation accuracy: 0.699400
# Epoch 59, CIFAR-10 Batch 2:  Loss:     0.1465, Validation accuracy: 0.691400
# Epoch 59, CIFAR-10 Batch 3:  Loss:     0.0732, Validation accuracy: 0.713800
# Epoch 59, CIFAR-10 Batch 4:  Loss:     0.0941, Validation accuracy: 0.708000
# Epoch 59, CIFAR-10 Batch 5:  Loss:     0.0897, Validation accuracy: 0.702600
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.1353, Validation accuracy: 0.712800
# Epoch 60, CIFAR-10 Batch 2:  Loss:     0.1369, Validation accuracy: 0.697600
# Epoch 60, CIFAR-10 Batch 3:  Loss:     0.0826, Validation accuracy: 0.709800
# Epoch 60, CIFAR-10 Batch 4:  Loss:     0.0956, Validation accuracy: 0.708600
# Epoch 60, CIFAR-10 Batch 5:  Loss:     0.0872, Validation accuracy: 0.719200
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.1430, Validation accuracy: 0.710000
# Epoch 61, CIFAR-10 Batch 2:  Loss:     0.1322, Validation accuracy: 0.697800
# Epoch 61, CIFAR-10 Batch 3:  Loss:     0.0699, Validation accuracy: 0.713000
# Epoch 61, CIFAR-10 Batch 4:  Loss:     0.1097, Validation accuracy: 0.699200
# Epoch 61, CIFAR-10 Batch 5:  Loss:     0.0934, Validation accuracy: 0.716600
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.1225, Validation accuracy: 0.712400
# Epoch 62, CIFAR-10 Batch 2:  Loss:     0.1251, Validation accuracy: 0.704600
# Epoch 62, CIFAR-10 Batch 3:  Loss:     0.0675, Validation accuracy: 0.711200
# Epoch 62, CIFAR-10 Batch 4:  Loss:     0.1124, Validation accuracy: 0.692800
# Epoch 62, CIFAR-10 Batch 5:  Loss:     0.0750, Validation accuracy: 0.690000
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.1272, Validation accuracy: 0.701800
# Epoch 63, CIFAR-10 Batch 2:  Loss:     0.1282, Validation accuracy: 0.711200
# Epoch 63, CIFAR-10 Batch 3:  Loss:     0.0684, Validation accuracy: 0.714000
# Epoch 63, CIFAR-10 Batch 4:  Loss:     0.0993, Validation accuracy: 0.703200
# Epoch 63, CIFAR-10 Batch 5:  Loss:     0.0632, Validation accuracy: 0.703000
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.1188, Validation accuracy: 0.684000
# Epoch 64, CIFAR-10 Batch 2:  Loss:     0.1247, Validation accuracy: 0.711400
# Epoch 64, CIFAR-10 Batch 3:  Loss:     0.0594, Validation accuracy: 0.715400
# Epoch 64, CIFAR-10 Batch 4:  Loss:     0.0879, Validation accuracy: 0.700400
# Epoch 64, CIFAR-10 Batch 5:  Loss:     0.0753, Validation accuracy: 0.700200
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.1273, Validation accuracy: 0.682400
# Epoch 65, CIFAR-10 Batch 2:  Loss:     0.1382, Validation accuracy: 0.706000
# Epoch 65, CIFAR-10 Batch 3:  Loss:     0.0705, Validation accuracy: 0.713600
# Epoch 65, CIFAR-10 Batch 4:  Loss:     0.0931, Validation accuracy: 0.689000
# Epoch 65, CIFAR-10 Batch 5:  Loss:     0.0696, Validation accuracy: 0.710800
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.1289, Validation accuracy: 0.678800
# Epoch 66, CIFAR-10 Batch 2:  Loss:     0.1271, Validation accuracy: 0.715800
# Epoch 66, CIFAR-10 Batch 3:  Loss:     0.0595, Validation accuracy: 0.713600
# Epoch 66, CIFAR-10 Batch 4:  Loss:     0.0823, Validation accuracy: 0.706800
# Epoch 66, CIFAR-10 Batch 5:  Loss:     0.0718, Validation accuracy: 0.712600
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.1276, Validation accuracy: 0.686400
# Epoch 67, CIFAR-10 Batch 2:  Loss:     0.1360, Validation accuracy: 0.710800
# Epoch 67, CIFAR-10 Batch 3:  Loss:     0.0573, Validation accuracy: 0.711400
# Epoch 67, CIFAR-10 Batch 4:  Loss:     0.0932, Validation accuracy: 0.697200
# Epoch 67, CIFAR-10 Batch 5:  Loss:     0.0618, Validation accuracy: 0.711600
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.1080, Validation accuracy: 0.685800
# Epoch 68, CIFAR-10 Batch 2:  Loss:     0.1043, Validation accuracy: 0.717400
# Epoch 68, CIFAR-10 Batch 3:  Loss:     0.0424, Validation accuracy: 0.702800
# Epoch 68, CIFAR-10 Batch 4:  Loss:     0.0934, Validation accuracy: 0.699400
# Epoch 68, CIFAR-10 Batch 5:  Loss:     0.0658, Validation accuracy: 0.706000
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.1400, Validation accuracy: 0.683600
# Epoch 69, CIFAR-10 Batch 2:  Loss:     0.1032, Validation accuracy: 0.712800
# Epoch 69, CIFAR-10 Batch 3:  Loss:     0.0467, Validation accuracy: 0.705000
# Epoch 69, CIFAR-10 Batch 4:  Loss:     0.0964, Validation accuracy: 0.700600
# Epoch 69, CIFAR-10 Batch 5:  Loss:     0.0566, Validation accuracy: 0.711400
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.1008, Validation accuracy: 0.690400
# Epoch 70, CIFAR-10 Batch 2:  Loss:     0.1132, Validation accuracy: 0.711800
# Epoch 70, CIFAR-10 Batch 3:  Loss:     0.0467, Validation accuracy: 0.708000
# Epoch 70, CIFAR-10 Batch 4:  Loss:     0.0791, Validation accuracy: 0.694800
# Epoch 70, CIFAR-10 Batch 5:  Loss:     0.0550, Validation accuracy: 0.713800
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.1203, Validation accuracy: 0.671800
# Epoch 71, CIFAR-10 Batch 2:  Loss:     0.1104, Validation accuracy: 0.706200
# Epoch 71, CIFAR-10 Batch 3:  Loss:     0.0458, Validation accuracy: 0.714200
# Epoch 71, CIFAR-10 Batch 4:  Loss:     0.0952, Validation accuracy: 0.696000
# Epoch 71, CIFAR-10 Batch 5:  Loss:     0.0463, Validation accuracy: 0.716200
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.1128, Validation accuracy: 0.668400
# Epoch 72, CIFAR-10 Batch 2:  Loss:     0.1180, Validation accuracy: 0.707800
# Epoch 72, CIFAR-10 Batch 3:  Loss:     0.0580, Validation accuracy: 0.706200
# Epoch 72, CIFAR-10 Batch 4:  Loss:     0.0806, Validation accuracy: 0.699000
# Epoch 72, CIFAR-10 Batch 5:  Loss:     0.0499, Validation accuracy: 0.709200
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.0823, Validation accuracy: 0.685200
# Epoch 73, CIFAR-10 Batch 2:  Loss:     0.0881, Validation accuracy: 0.704800
# Epoch 73, CIFAR-10 Batch 3:  Loss:     0.0614, Validation accuracy: 0.707400
# Epoch 73, CIFAR-10 Batch 4:  Loss:     0.0872, Validation accuracy: 0.698200
# Epoch 73, CIFAR-10 Batch 5:  Loss:     0.0535, Validation accuracy: 0.711600
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.0832, Validation accuracy: 0.684800
# Epoch 74, CIFAR-10 Batch 2:  Loss:     0.0998, Validation accuracy: 0.696600
# Epoch 74, CIFAR-10 Batch 3:  Loss:     0.0469, Validation accuracy: 0.704400
# Epoch 74, CIFAR-10 Batch 4:  Loss:     0.0833, Validation accuracy: 0.696800
# Epoch 74, CIFAR-10 Batch 5:  Loss:     0.0529, Validation accuracy: 0.718800
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.0841, Validation accuracy: 0.694400
# Epoch 75, CIFAR-10 Batch 2:  Loss:     0.0946, Validation accuracy: 0.698000
# Epoch 75, CIFAR-10 Batch 3:  Loss:     0.0431, Validation accuracy: 0.714800
# Epoch 75, CIFAR-10 Batch 4:  Loss:     0.0805, Validation accuracy: 0.707600
# Epoch 75, CIFAR-10 Batch 5:  Loss:     0.0485, Validation accuracy: 0.709400
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.0697, Validation accuracy: 0.711400
# Epoch 76, CIFAR-10 Batch 2:  Loss:     0.0928, Validation accuracy: 0.697800
# Epoch 76, CIFAR-10 Batch 3:  Loss:     0.0532, Validation accuracy: 0.710000
# Epoch 76, CIFAR-10 Batch 4:  Loss:     0.0872, Validation accuracy: 0.699600
# Epoch 76, CIFAR-10 Batch 5:  Loss:     0.0424, Validation accuracy: 0.710600
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.0746, Validation accuracy: 0.707000
# Epoch 77, CIFAR-10 Batch 2:  Loss:     0.0833, Validation accuracy: 0.694800
# Epoch 77, CIFAR-10 Batch 3:  Loss:     0.0517, Validation accuracy: 0.707600
# Epoch 77, CIFAR-10 Batch 4:  Loss:     0.0597, Validation accuracy: 0.706400
# Epoch 77, CIFAR-10 Batch 5:  Loss:     0.0453, Validation accuracy: 0.713400
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.0628, Validation accuracy: 0.704400
# Epoch 78, CIFAR-10 Batch 2:  Loss:     0.0836, Validation accuracy: 0.696000
# Epoch 78, CIFAR-10 Batch 3:  Loss:     0.0544, Validation accuracy: 0.701000
# Epoch 78, CIFAR-10 Batch 4:  Loss:     0.0713, Validation accuracy: 0.711200
# Epoch 78, CIFAR-10 Batch 5:  Loss:     0.0498, Validation accuracy: 0.717800
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.0622, Validation accuracy: 0.708800
# Epoch 79, CIFAR-10 Batch 2:  Loss:     0.0945, Validation accuracy: 0.694200
# Epoch 79, CIFAR-10 Batch 3:  Loss:     0.0516, Validation accuracy: 0.709800
# Epoch 79, CIFAR-10 Batch 4:  Loss:     0.0601, Validation accuracy: 0.705200
# Epoch 79, CIFAR-10 Batch 5:  Loss:     0.0382, Validation accuracy: 0.708200
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.0648, Validation accuracy: 0.702000
# Epoch 80, CIFAR-10 Batch 2:  Loss:     0.0875, Validation accuracy: 0.698800
# Epoch 80, CIFAR-10 Batch 3:  Loss:     0.0447, Validation accuracy: 0.712800
# Epoch 80, CIFAR-10 Batch 4:  Loss:     0.0705, Validation accuracy: 0.706200
# Epoch 80, CIFAR-10 Batch 5:  Loss:     0.0411, Validation accuracy: 0.704600
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.0505, Validation accuracy: 0.695800
# Epoch 81, CIFAR-10 Batch 2:  Loss:     0.0879, Validation accuracy: 0.699000
# Epoch 81, CIFAR-10 Batch 3:  Loss:     0.0576, Validation accuracy: 0.712600
# Epoch 81, CIFAR-10 Batch 4:  Loss:     0.0642, Validation accuracy: 0.703600
# Epoch 81, CIFAR-10 Batch 5:  Loss:     0.0524, Validation accuracy: 0.696000
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.0596, Validation accuracy: 0.709400
# Epoch 82, CIFAR-10 Batch 2:  Loss:     0.0864, Validation accuracy: 0.696200
# Epoch 82, CIFAR-10 Batch 3:  Loss:     0.0508, Validation accuracy: 0.709800
# Epoch 82, CIFAR-10 Batch 4:  Loss:     0.0524, Validation accuracy: 0.701600
# Epoch 82, CIFAR-10 Batch 5:  Loss:     0.0417, Validation accuracy: 0.703600
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.0673, Validation accuracy: 0.707400
# Epoch 83, CIFAR-10 Batch 2:  Loss:     0.0813, Validation accuracy: 0.701000
# Epoch 83, CIFAR-10 Batch 3:  Loss:     0.0399, Validation accuracy: 0.711400
# Epoch 83, CIFAR-10 Batch 4:  Loss:     0.0524, Validation accuracy: 0.704400
# Epoch 83, CIFAR-10 Batch 5:  Loss:     0.0473, Validation accuracy: 0.709200
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.0556, Validation accuracy: 0.709000
# Epoch 84, CIFAR-10 Batch 2:  Loss:     0.0884, Validation accuracy: 0.701000
# Epoch 84, CIFAR-10 Batch 3:  Loss:     0.0455, Validation accuracy: 0.706600
# Epoch 84, CIFAR-10 Batch 4:  Loss:     0.0648, Validation accuracy: 0.704000
# Epoch 84, CIFAR-10 Batch 5:  Loss:     0.0353, Validation accuracy: 0.700600
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.0566, Validation accuracy: 0.705800
# Epoch 85, CIFAR-10 Batch 2:  Loss:     0.0730, Validation accuracy: 0.697400
# Epoch 85, CIFAR-10 Batch 3:  Loss:     0.0361, Validation accuracy: 0.710200
# Epoch 85, CIFAR-10 Batch 4:  Loss:     0.0505, Validation accuracy: 0.711000
# Epoch 85, CIFAR-10 Batch 5:  Loss:     0.0385, Validation accuracy: 0.708200
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.0631, Validation accuracy: 0.706800
# Epoch 86, CIFAR-10 Batch 2:  Loss:     0.0873, Validation accuracy: 0.700200
# Epoch 86, CIFAR-10 Batch 3:  Loss:     0.0309, Validation accuracy: 0.711000
# Epoch 86, CIFAR-10 Batch 4:  Loss:     0.0613, Validation accuracy: 0.703600
# Epoch 86, CIFAR-10 Batch 5:  Loss:     0.0381, Validation accuracy: 0.703600
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.0387, Validation accuracy: 0.710800
# Epoch 87, CIFAR-10 Batch 2:  Loss:     0.0867, Validation accuracy: 0.694000
# Epoch 87, CIFAR-10 Batch 3:  Loss:     0.0315, Validation accuracy: 0.708400
# Epoch 87, CIFAR-10 Batch 4:  Loss:     0.0696, Validation accuracy: 0.692200
# Epoch 87, CIFAR-10 Batch 5:  Loss:     0.0338, Validation accuracy: 0.705800
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.0479, Validation accuracy: 0.699400
# Epoch 88, CIFAR-10 Batch 2:  Loss:     0.0783, Validation accuracy: 0.699200
# Epoch 88, CIFAR-10 Batch 3:  Loss:     0.0290, Validation accuracy: 0.704000
# Epoch 88, CIFAR-10 Batch 4:  Loss:     0.0563, Validation accuracy: 0.692600
# Epoch 88, CIFAR-10 Batch 5:  Loss:     0.0368, Validation accuracy: 0.705800
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.0431, Validation accuracy: 0.708600
# Epoch 89, CIFAR-10 Batch 2:  Loss:     0.0787, Validation accuracy: 0.701000
# Epoch 89, CIFAR-10 Batch 3:  Loss:     0.0281, Validation accuracy: 0.711200
# Epoch 89, CIFAR-10 Batch 4:  Loss:     0.0511, Validation accuracy: 0.707200
# Epoch 89, CIFAR-10 Batch 5:  Loss:     0.0435, Validation accuracy: 0.692000
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.0435, Validation accuracy: 0.700000
# Epoch 90, CIFAR-10 Batch 2:  Loss:     0.0802, Validation accuracy: 0.703600
# Epoch 90, CIFAR-10 Batch 3:  Loss:     0.0250, Validation accuracy: 0.714000
# Epoch 90, CIFAR-10 Batch 4:  Loss:     0.0502, Validation accuracy: 0.695600
# Epoch 90, CIFAR-10 Batch 5:  Loss:     0.0412, Validation accuracy: 0.702000
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.0458, Validation accuracy: 0.696800
# Epoch 91, CIFAR-10 Batch 2:  Loss:     0.0775, Validation accuracy: 0.695000
# Epoch 91, CIFAR-10 Batch 3:  Loss:     0.0223, Validation accuracy: 0.714000
# Epoch 91, CIFAR-10 Batch 4:  Loss:     0.0399, Validation accuracy: 0.706000
# Epoch 91, CIFAR-10 Batch 5:  Loss:     0.0395, Validation accuracy: 0.698600
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.0527, Validation accuracy: 0.701200
# Epoch 92, CIFAR-10 Batch 2:  Loss:     0.0807, Validation accuracy: 0.697600
# Epoch 92, CIFAR-10 Batch 3:  Loss:     0.0293, Validation accuracy: 0.710800
# Epoch 92, CIFAR-10 Batch 4:  Loss:     0.0480, Validation accuracy: 0.707200
# Epoch 92, CIFAR-10 Batch 5:  Loss:     0.0517, Validation accuracy: 0.705000
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.0415, Validation accuracy: 0.695000
# Epoch 93, CIFAR-10 Batch 2:  Loss:     0.0668, Validation accuracy: 0.703400
# Epoch 93, CIFAR-10 Batch 3:  Loss:     0.0236, Validation accuracy: 0.705400
# Epoch 93, CIFAR-10 Batch 4:  Loss:     0.0425, Validation accuracy: 0.704800
# Epoch 93, CIFAR-10 Batch 5:  Loss:     0.0439, Validation accuracy: 0.697800
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.0381, Validation accuracy: 0.703200
# Epoch 94, CIFAR-10 Batch 2:  Loss:     0.0629, Validation accuracy: 0.701400
# Epoch 94, CIFAR-10 Batch 3:  Loss:     0.0211, Validation accuracy: 0.710400
# Epoch 94, CIFAR-10 Batch 4:  Loss:     0.0520, Validation accuracy: 0.692800
# Epoch 94, CIFAR-10 Batch 5:  Loss:     0.0381, Validation accuracy: 0.703200
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.0387, Validation accuracy: 0.701000
# Epoch 95, CIFAR-10 Batch 2:  Loss:     0.0538, Validation accuracy: 0.703600
# Epoch 95, CIFAR-10 Batch 3:  Loss:     0.0257, Validation accuracy: 0.713800
# Epoch 95, CIFAR-10 Batch 4:  Loss:     0.0542, Validation accuracy: 0.696800
# Epoch 95, CIFAR-10 Batch 5:  Loss:     0.0519, Validation accuracy: 0.701000
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.0317, Validation accuracy: 0.699600
# Epoch 96, CIFAR-10 Batch 2:  Loss:     0.0609, Validation accuracy: 0.705800
# Epoch 96, CIFAR-10 Batch 3:  Loss:     0.0178, Validation accuracy: 0.711600
# Epoch 96, CIFAR-10 Batch 4:  Loss:     0.0512, Validation accuracy: 0.691600
# Epoch 96, CIFAR-10 Batch 5:  Loss:     0.0333, Validation accuracy: 0.704800
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.0430, Validation accuracy: 0.707800
# Epoch 97, CIFAR-10 Batch 2:  Loss:     0.0512, Validation accuracy: 0.702000
# Epoch 97, CIFAR-10 Batch 3:  Loss:     0.0220, Validation accuracy: 0.712800
# Epoch 97, CIFAR-10 Batch 4:  Loss:     0.0523, Validation accuracy: 0.681200
# Epoch 97, CIFAR-10 Batch 5:  Loss:     0.0259, Validation accuracy: 0.711600
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.0284, Validation accuracy: 0.705000
# Epoch 98, CIFAR-10 Batch 2:  Loss:     0.0510, Validation accuracy: 0.710600
# Epoch 98, CIFAR-10 Batch 3:  Loss:     0.0233, Validation accuracy: 0.708600
# Epoch 98, CIFAR-10 Batch 4:  Loss:     0.0604, Validation accuracy: 0.671800
# Epoch 98, CIFAR-10 Batch 5:  Loss:     0.0334, Validation accuracy: 0.702400
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.0330, Validation accuracy: 0.706400
# Epoch 99, CIFAR-10 Batch 2:  Loss:     0.0497, Validation accuracy: 0.705000
# Epoch 99, CIFAR-10 Batch 3:  Loss:     0.0170, Validation accuracy: 0.706600
# Epoch 99, CIFAR-10 Batch 4:  Loss:     0.0579, Validation accuracy: 0.681200
# Epoch 99, CIFAR-10 Batch 5:  Loss:     0.0421, Validation accuracy: 0.707000
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.0362, Validation accuracy: 0.695400
# Epoch 100, CIFAR-10 Batch 2:  Loss:     0.0536, Validation accuracy: 0.709600
# Epoch 100, CIFAR-10 Batch 3:  Loss:     0.0283, Validation accuracy: 0.708800
# Epoch 100, CIFAR-10 Batch 4:  Loss:     0.0505, Validation accuracy: 0.691200
# Epoch 100, CIFAR-10 Batch 5:  Loss:     0.0315, Validation accuracy: 0.709200

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.69892578125

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
